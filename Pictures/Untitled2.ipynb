# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import plotly as plt

# %%
data=pd.read_csv(r"james_bond_data.csv")

# %%
data.head(10)
# Out:
#            Release                            Movie            Bond  \
# 0       June, 1962                           Dr. No    Sean Connery
# 1     August, 1963            From Russia with Love    Sean Connery
# 2        May, 1964                       Goldfinger    Sean Connery
# 3  September, 1965                      Thunderball    Sean Connery
# 4   November, 1967              You Only Live Twice    Sean Connery
# 5       July, 1969  On Her Majesty's Secret Service  George Lazenby
# 6      March, 1971             Diamonds Are Forever   Shawn Connery
# 7     August, 1973                 Live and Let Die     Roger Moore
# 8       July, 1974      The Man with the Golden Gun     Roger Moore
# 9       July, 1974      The Man with the Golden Gun     Roger Moore
#
#    Bond_Car_MFG         US_Gross       World_Gross Budget_Movie Film_Length  \
# 0       Sunbeam  $16,067,035.00    $59,567,035.00    $1,000.00     110 mins
# ...

# %%
data.tail(8)
# Out:
#             Release                    Movie            Bond  Bond_Car_MFG  \
# 19       July, 1997      Tomorrow Never Dies  Pierce Brosnan  Aston Martin
# 20       June, 1999  The World Is Not Enough  Pierce Brosnan           BMW
# 21     August, 2002          Die Another Day  Pierce Brosnan  Aston Martin
# 22   February, 2006            Casino Royale    Daniel Craig  Astin Martin
# 23   December, 2008        Quantum of Solace    Daniel Craig  Aston Martin
# 24   November, 2012                  Skyfall    Daniel Craig  Astin Martin
# 25  September, 2015                  Spectre    Daniel Craig  Aston Martin
# 26   November, 2021           No Time to Die    Daniel Craig  Aston Martin
#
#             US_Gross         World_Gross  Budget_Movie Film_Length  \
# 19  $125,304,276.00     $339,504,276.00   $110,000.00     119 mins
# 20  $126,930,660.00     $361,730,660.00   $135,000.00     128 mins
# 21  $160,942,139.00     $431,942,139.00   $142,000.00     133 mins
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Release           27 non-null     object
#  1   Movie             27 non-null     object
#  2   Bond              27 non-null     object
#  3   Bond_Car_MFG      27 non-null     object
#  4   US_Gross          27 non-null     object
#  5   World_Gross       27 non-null     object
#  6   Budget_Movie      27 non-null     object
#  7   Film_Length       27 non-null     object
#  8   Avg_User_IMDB     26 non-null     float64
#  9   Avg_User_Rtn_Tom  26 non-null     float64
#  10  Martinis          27 non-null     int64
#  11  Kills_Bond        27 non-null     int64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 2.7+ KB

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 2
#       1 data= (
# ----> 2 data.rename.combine_first(
#       3 pd.DataFrame ({"Avg_User_IMDB":{10:7.1},"Avg_user_Rtn_Tom":{10:6.8}})
#       4 )
#       5 .assign(
#       6     World_Gross=lambda data:(
#       7 data["World_Gross"]
#       8 .replace("[$,],","",regex=TRUE)
#       9 .astype("float64")
#      10 )))
#      11 data.head()
#
# AttributeError: 'function' object has no attribute 'combine_first'

# %%
print(data.to_string())
# Out:
#             Release                            Movie            Bond  Bond_Car_MFG          US_Gross         World_Gross  Budget_Movie Film_Length  Avg_User_IMDB  Avg_User_Rtn_Tom  Martinis  Kills_Bond
# 0        June, 1962                           Dr. No    Sean Connery       Sunbeam   $16,067,035.00      $59,567,035.00     $1,000.00     110 mins            7.3               7.7         2           4
# 1      August, 1963            From Russia with Love    Sean Connery       Bentley   $24,800,000.00      $78,900,000.00     $2,000.00     115 mins            7.5               8.0         0          11
# 2         May, 1964                       Goldfinger    Sean Connery  Aston Martin   $51,100,000.00     $124,900,000.00     $3,000.00     110 mins            7.8               8.4         1           9
# ...

# %%
data= (
data.rename(columns= new_columns_names).combine_first(
pd.DataFrame ({"Avg_User_IMDB":{10:7.1},"Avg_user_Rtn_Tom":{10:6.8}})
)
.assign( 
    World_Gross=lambda data:(
data["World_Gross"]
.replace("[$,],","",regex=T)
.astype("float64")
)))
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 data= (
# ----> 2 data.rename(columns= new_columns_names).combine_first(
#       3 pd.DataFrame ({"Avg_User_IMDB":{10:7.1},"Avg_user_Rtn_Tom":{10:6.8}})
#       4 )
#       5 .assign(
#       6     World_Gross=lambda data:(
#       7 data["World_Gross"]
#       8 .replace("[$,],","",regex=T)
#       9 .astype("float64")
#      10 )))
#      11 data.head()
#
# NameError: name 'new_columns_names' is not defined

# %%
data=data.rename(column=new_column)
data.column
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 data=data.rename(column=new_column)
#       2 data.column
#
# NameError: name 'new_column' is not defined

# %%
data["Martinis"].describe()
# Out:
# count    27.000000
# mean      0.629630
# std       1.547905
# min      -6.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       3.000000
# Name: Martinis, dtype: float64

# %%
data["Martinis"]=data["Martinis"].fillna(data["Martinis"].mean())

# %%
data.loc[data.isna().any(axis="columns")]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Release           27 non-null     object
#  1   Movie             27 non-null     object
#  2   Bond              27 non-null     object
#  3   Bond_Car_MFG      27 non-null     object
#  4   US_Gross          27 non-null     object
#  5   World_Gross       27 non-null     object
#  6   Budget_Movie      27 non-null     object
#  7   Film_Length       27 non-null     object
#  8   Avg_User_IMDB     26 non-null     float64
#  9   Avg_User_Rtn_Tom  26 non-null     float64
#  10  Martinis          27 non-null     int64
#  11  Kills_Bond        27 non-null     int64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 2.7+ KB

# %%
data.isnull().sum()
# Out:
# Release             0
# Movie               0
# Bond                0
# Bond_Car_MFG        0
# US_Gross            0
# World_Gross         0
# Budget_Movie        0
# Film_Length         0
# Avg_User_IMDB       1
# Avg_User_Rtn_Tom    1
# Martinis            0
# Kills_Bond          0
# dtype: int64

# %%
data["Avg_User_IMDB "] =data["Avg_User_IMDB "].fillna(data["Avg_User_IMDB "].median())
 data["Avg_User_Rtn_Tom  "]=data["Avg_User_Rtn_Tom  "].fillna(data[" Avg_User_Rtn_Tom "].median())
data.isnull().sum()
# Out:
#   Cell In[50], line 2
#     data["Avg_User_Rtn_Tom  "]=data["Avg_User_Rtn_Tom  "].fillna(data[" Avg_User_Rtn_Tom "].median())
#     ^
# IndentationError: unexpected indent

# %%
git init
# Out:
#   Cell In[1], line 1
#     git init
#         ^
# SyntaxError: invalid syntax
